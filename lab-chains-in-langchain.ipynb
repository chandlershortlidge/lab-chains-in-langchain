# %% [markdown]
# # Lab | Chains in LangChain
#
# ## Outline
#
# * LLMChain
# * Sequential Chains
#   * SimpleSequentialChain
#   * SequentialChain
# * Router Chain

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')
HUGGINGFACEHUB_API_TOKEN = os.getenv('HUGGINGFACEHUB_API_TOKEN')

# %%
#!pip install pandas

# %%
import pandas as pd
df = pd.read_csv('/Users/chandlershortlidge/Desktop/Ironhack/lab-chains-in-langchain/data/Data.csv')

# %%
df.head()
# Out:
#                    Product                                             Review
# 0     Queen Size Sheet Set  I ordered a king size set. My only criticism w...
# 1   Waterproof Phone Pouch  I loved the waterproof sac, although the openi...
# 2      Luxury Air Mattress  This mattress had a small hole in the top of i...
# 3           Pillows Insert  This is the best throw pillow fillers on Amazo...
# 4  Milk Frother Handheld\n   I loved this product. But they only seem to l...

# %%
(df[df["Product"] == "Queen Size Sheet Set"])
# Out:
#                 Product                                             Review
# 0  Queen Size Sheet Set  I ordered a king size set. My only criticism w...

# %% [markdown]
# ## LLMChain

# %%
# !pip install langchain_community
# Out:
# Requirement already satisfied: langchain_community in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (0.3.31)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (0.3.83)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (0.6.8)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain_community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langchain-core<2.0.0,>=0.3.78->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.78->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.11.0)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/rag-practice/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
#Replace None by your own value and justify
llm = ChatOpenAI(model='gpt-4o',
    temperature=0.7)

# %%
prompt = ChatPromptTemplate.from_template("Please describe this product {product}"
 
)

# %%
chain = prompt | llm

# %%
product = "Queen Size Sheet Set"
response = chain.invoke({"product": product})
print(response)
# Out:
# content='A queen size sheet set typically includes several pieces designed to fit a standard queen size bed, which measures approximately 60 inches wide by 80 inches long. The set usually consists of the following components:\n\n1. **Fitted Sheet**: This sheet has elastic corners to ensure a snug fit around the mattress. It is designed to accommodate mattresses of varying depths, often ranging from 8 to 18 inches, depending on the specific product.\n\n2. **Flat Sheet**: Also known as a top sheet, this piece lies between the sleeper and the comforter or blanket. It provides an additional layer of warmth and is often used to protect the blanket from getting dirty.\n\n3. **Pillowcases**: A queen size sheet set typically includes two pillowcases. They are designed to fit standard or queen size pillows, which measure approximately 20 inches by 30 inches.\n\nThe material of a queen size sheet set can vary widely, with common options including cotton, microfiber, bamboo, linen, and polyester. Each material has its own characteristics in terms of softness, breathability, durability, and ease of care. Cotton, for example, is known for its softness and breathability, while microfiber is appreciated for its affordability and wrinkle resistance.\n\nThread count is another important factor, especially for cotton sheets, as it indicates the number of threads per square inch of fabric. Generally, a higher thread count can mean a softer and more durable sheet, but this is not always the case, as the quality of the threads also plays a significant role.\n\nQueen size sheet sets come in a wide range of colors, patterns, and designs to match different bedroom decor styles. They may also feature special finishes, such as wrinkle-resistant or cooling technologies, to enhance their functionality and comfort.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 353, 'prompt_tokens': 15, 'total_tokens': 368, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ad98c18a04', 'id': 'chatcmpl-D7I33gI54dJPKmbE19z04YSJxRfPg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--019c41c6-5d8c-7500-acac-b15cb47cb3ea-0' usage_metadata={'input_tokens': 15, 'output_tokens': 353, 'total_tokens': 368, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## SimpleSequentialChain

# %%
from langchain.chains import SimpleSequentialChain

# %%
llm = ChatOpenAI(temperature=0.9)

# prompt template 1
first_prompt = ChatPromptTemplate.from_template(
    "What is the best name to describe a company that makes {product}?"
)

# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt)

# %%
# prompt template 2
second_prompt = ChatPromptTemplate.from_template(
    "Write a 20-word description for the following company: {text}"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt)

# %%
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],
                                             verbose=True
                                            )

# %%
overall_simple_chain.run(product)

# %%
overall_simple_chain.run("Waterproof Phone Pouch")

# %%
overall_simple_chain.run("Luxury Air Mattress")

# %% [markdown]
# **Repeat the above twice for different products**

# %% [markdown]
# ## SequentialChain

# %%
from langchain.chains import SequentialChain

# %%
llm = ChatOpenAI(temperature=0.9)


first_prompt = ChatPromptTemplate.from_template(
    "Translate the following review to English:\n\n{Review}"
)

chain_one = LLMChain(llm=llm, prompt=first_prompt, 
                     output_key="English_Review"
                    )

# %%
second_prompt = ChatPromptTemplate.from_template(
    "Can you summarize the following review in 1 sentence:\n\n{English_Review}"
)

chain_two = LLMChain(llm=llm, prompt=second_prompt, 
                     output_key="summary"
                    )

# %%
# prompt template 3: detect the language of the review
third_prompt = ChatPromptTemplate.from_template(
    "What language is the following review written in:\n\n{Review}"
)
# chain 3: input= Review and output= language
chain_three = LLMChain(llm=llm, prompt=third_prompt,
                       output_key="language"
                      )

# %%
# prompt template 4: follow up message using summary and language
fourth_prompt = ChatPromptTemplate.from_template(
    "Write a follow up response to the following "
    "summary in the specified language:"
    "\n\nSummary: {summary}\n\nLanguage: {language}"
)
chain_four = LLMChain(llm=llm, prompt=fourth_prompt,
                      output_key="followup_message"
                     )

# %%
# overall_chain: input= Review 
# and output= English_Review,summary, followup_message
overall_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables=["Review"],
    output_variables=["English_Review", "summary", "followup_message"],
    verbose=True
)

# %%
review = df.Review[5]
overall_chain(review)

# %%
review = df.Review[0]
overall_chain(review)

# %%
review = df.Review[2]
overall_chain(review)

# %% [markdown]
# **Repeat the above twice for different products or reviews**

# %% [markdown]
# ## Router Chain

# %%
physics_template = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise\
and easy to understand manner. \
When you don't know the answer to a question you admit\
that you don't know.

Here is a question:
{input}"""


math_template = """You are a very good mathematician. \
You are great at answering math questions. \
You are so good because you are able to break down \
hard problems into their component parts, 
answer the component parts, and then put them together\
to answer the broader question.

Here is a question:
{input}"""

history_template = """You are a very good historian. \
You have an excellent knowledge of and understanding of people,\
events and contexts from a range of historical periods. \
You have the ability to think, reflect, debate, discuss and \
evaluate the past. You have a respect for historical evidence\
and the ability to make use of it to support your explanations \
and judgements.

Here is a question:
{input}"""


computerscience_template = """ You are a successful computer scientist.\
You have a passion for creativity, collaboration,\
forward-thinking, confidence, strong problem-solving capabilities,\
understanding of theories and algorithms, and excellent communication \
skills. You are great at answering coding questions. \
You are so good because you know how to solve a problem by \
describing the solution in imperative steps \
that a machine can easily interpret and you know how to \
choose a solution that has a good balance between \
time complexity and space complexity. 

Here is a question:
{input}"""

biology_template = """You are an excellent biologist. \
You have a deep understanding of living organisms, \
from the molecular and cellular level to entire ecosystems. \
You are skilled at observing patterns in nature, analyzing biological data, \
and explaining complex processes like evolution, genetics, physiology, and ecology. \
You can clearly communicate how life functions and adapts, \
and you make connections between different biological concepts \
to answer challenging questions.

Here is a question:
{input}"""

# %%
prompt_infos = [
    {
        "name": "physics", 
        "description": "Good for answering questions about physics", 
        "prompt_template": physics_template
    },
    {
        "name": "math", 
        "description": "Good for answering math questions", 
        "prompt_template": math_template
    },
    {
        "name": "History", 
        "description": "Good for answering history questions", 
        "prompt_template": history_template
    },
    {
        "name": "computer science", 
        "description": "Good for answering computer science questions", 
        "prompt_template": computerscience_template
    },
    {
        "name": "biology",
        "description": "Good for answering biology questions",
        "prompt_template": biology_template
    }
]

# %%
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
from langchain.prompts import PromptTemplate

# %%
llm = ChatOpenAI(temperature=0)

# %%
destination_chains = {}
for p_info in prompt_infos:
    name = p_info["name"]
    prompt_template = p_info["prompt_template"]
    prompt = ChatPromptTemplate.from_template(template=prompt_template)
    chain = LLMChain(llm=llm, prompt=prompt)
    destination_chains[name] = chain  
    
destinations = [f"{p['name']}: {p['description']}" for p in prompt_infos]
destinations_str = "\n".join(destinations)

# %%
default_prompt = ChatPromptTemplate.from_template("{input}")
default_chain = LLMChain(llm=llm, prompt=default_prompt)

# %%
MULTI_PROMPT_ROUTER_TEMPLATE = """Given a raw text input to a \
language model select the model prompt best suited for the input. \
You will be given the names of the available prompts and a \
description of what the prompt is best suited for. \
You may also revise the original input if you think that revising\
it will ultimately lead to a better response from the language model.

<< FORMATTING >>
Return a markdown code snippet with a JSON object formatted to look like:
```json
{{{{
    "destination": string \ name of the prompt to use or "DEFAULT"
    "next_inputs": string \ a potentially modified version of the original input
}}}}
```

REMEMBER: "destination" MUST be one of the candidate prompt \
names specified below OR it can be "DEFAULT" if the input is not\
well suited for any of the candidate prompts.
REMEMBER: "next_inputs" can just be the original input \
if you don't think any modifications are needed.

<< CANDIDATE PROMPTS >>
{destinations}

<< INPUT >>
{{input}}

<< OUTPUT (remember to include the ```json)>>"""

# %%
router_template = MULTI_PROMPT_ROUTER_TEMPLATE.format(
    destinations=destinations_str
)
router_prompt = PromptTemplate(
    template=router_template,
    input_variables=["input"],
    output_parser=RouterOutputParser(),
)

router_chain = LLMRouterChain.from_llm(llm, router_prompt)

# %%
chain = MultiPromptChain(router_chain=router_chain, 
                         destination_chains=destination_chains, 
                         default_chain=default_chain, verbose=True
                        )

# %%
chain.run("What is black body radiation?")

# %%
chain.run("what is 2 + 2")

# %%
chain.run("Why does every cell in our body contain DNA?")

# %%
chain.run("What were the main causes of World War I?")

# %%
chain.run("What is the time complexity of binary search?")

# %% [markdown]
# **Repeat the above at least once for different inputs and chains executions - Be creative!**
